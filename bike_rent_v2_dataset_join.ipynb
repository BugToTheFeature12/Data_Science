# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
weather = pd.read_csv("C:\\Users\\nagyn\\Documents\\bi_analyst_assignment_bubi (2)\\bi_analyst_assignment_bubi\\bubi_dataset\\bubi_dataset_home_work_nagy_norbert\\weather_data2.csv")
location = pd.read_csv("C:\\Users\\nagyn\\Documents\\bi_analyst_assignment_bubi (2)\\bi_analyst_assignment_bubi\\bubi_dataset\\bubi_dataset_home_work_nagy_norbert\\train_data2.csv")
#merged_df = pd.read_csv("C:\\Users\\nagyn\\Documents\\bi_analyst_assignment_bubi (2)\\bi_analyst_assignment_bubi\\bubi_dataset\\bubi_dataset_home_work_nagy_norbert\\merged_df2.csv")

# %%
location
# Out:
#         bicycle_id           start_time             end_time  start_location  \
# 0            86602  2015-01-01 00:04:00  2015-01-01 00:10:00             802
# 1            86157  2015-01-01 00:04:00  2015-01-01 00:16:00             802
# 2            86091  2015-01-01 00:08:00  2015-01-01 00:32:00             513
# 3            86908  2015-01-01 00:09:00  2015-01-01 00:29:00             513
# 4            86758  2015-01-01 00:10:00  2015-01-01 00:11:00             508
# ...            ...                  ...                  ...             ...
# 135479       86568  2015-05-31 23:45:00  2015-06-01 00:00:00             507
# 135480       86166  2015-05-31 23:46:00  2015-06-01 00:01:00             804
# 135481       86201  2015-05-31 23:46:00  2015-06-01 00:01:00             804
# 135482       86909  2015-05-31 23:52:00  2015-06-01 00:03:00             505
# 135483       86544  2015-05-31 23:54:00  2015-06-01 00:04:00            1302
#
# ...

# %%
weather
# Out:
#                      time  tempm  hum  wspdm  pressurem  windchillm  fog  \
# 0     2015-01-01 00:00:00    -12   85    5.6       1037       -15.5    0
# 1     2015-01-01 00:30:00    -11   85    3.7       1036       -13.0    0
# 2     2015-01-01 01:00:00    -10   86    3.7       1036       -12.0    0
# 3     2015-01-01 01:30:00    -10   86    0.0       1036       -12.0    0
# 4     2015-01-01 02:00:00     -9   79    0.0       1036       -11.0    0
# ...                   ...    ...  ...    ...        ...         ...  ...
# 7230  2015-05-31 21:30:00     16   77    3.7       1019        14.0    0
# 7231  2015-05-31 22:00:00     14   88    3.7       1019        12.0    0
# 7232  2015-05-31 22:30:00     14   88    3.7       1019        12.0    0
# 7233  2015-05-31 23:00:00     15   82    3.7       1019        13.0    0
# 7234  2015-05-31 23:30:00     13   94    1.9       1019        11.0    0
#
#       rain  snow  hail  thunder      merge_id_w
# ...

# %%
weather.info()
location.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7235 entries, 0 to 7234
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   time        7235 non-null   object
#  1   tempm       7235 non-null   int64
#  2   hum         7235 non-null   int64
#  3   wspdm       7235 non-null   float64
#  4   pressurem   7235 non-null   int64
#  5   windchillm  7235 non-null   float64
#  6   fog         7235 non-null   int64
#  7   rain        7235 non-null   int64
#  8   snow        7235 non-null   int64
#  9   hail        7235 non-null   int64
#  10  thunder     7235 non-null   int64
#  11  merge_id_w  7235 non-null   int64
# dtypes: float64(2), int64(9), object(1)
# memory usage: 678.4+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135484 entries, 0 to 135483
# Data columns (total 8 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
# ...

# %%
weather.head()
# Out:
#                   time  tempm  hum  wspdm  pressurem  windchillm  fog  rain  \
# 0  2015-01-01 00:00:00    -12   85    5.6       1037       -15.5    0     0
# 1  2015-01-01 00:30:00    -11   85    3.7       1036       -13.0    0     0
# 2  2015-01-01 01:00:00    -10   86    3.7       1036       -12.0    0     0
# 3  2015-01-01 01:30:00    -10   86    0.0       1036       -12.0    0     0
# 4  2015-01-01 02:00:00     -9   79    0.0       1036       -11.0    0     0
#
#    snow  hail  thunder      merge_id_w
# 0     0     0        0  20150101000000
# 1     0     0        0  20150101003000
# 2     0     0        0  20150101010000
# 3     0     0        0  20150101013000
# 4     0     0        0  20150101020000

# %%
location.head()
# Out:
#    bicycle_id           start_time             end_time  start_location  \
# 0       86602  2015-01-01 00:04:00  2015-01-01 00:10:00             802
# 1       86157  2015-01-01 00:04:00  2015-01-01 00:16:00             802
# 2       86091  2015-01-01 00:08:00  2015-01-01 00:32:00             513
# 3       86908  2015-01-01 00:09:00  2015-01-01 00:29:00             513
# 4       86758  2015-01-01 00:10:00  2015-01-01 00:11:00             508
#
#    end_location rounded_start_time       year_month_day        merge_id
# 0           508           00:00:00  2015-01-01 00:00:00  20150101000000
# 1           508           00:00:00  2015-01-01 00:00:00  20150101000000
# 2          1106           00:00:00  2015-01-01 00:00:00  20150101000000
# 3           604           00:00:00  2015-01-01 00:00:00  20150101000000
# 4           508           00:00:00  2015-01-01 00:00:00  20150101000000

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135484 entries, 0 to 135483
# Data columns (total 22 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Unnamed: 0          135484 non-null  int64
#  1   bicycle_id          135484 non-null  int64
#  2   start_time          135484 non-null  object
#  3   end_time            135484 non-null  object
#  4   start_location      135484 non-null  int64
#  5   end_location        135484 non-null  int64
#  6   rounded_start_time  135484 non-null  object
#  7   year_month_day      135484 non-null  object
#  8   merge_id            135484 non-null  int64
#  9   time                135294 non-null  object
#  10  tempm               135294 non-null  float64
#  11  hum                 135294 non-null  float64
#  12  wspdm               135294 non-null  float64
#  13  pressurem           135294 non-null  float64
#  14  windchillm          135294 non-null  float64
# ...

# %%
merged_df
# Out:
#         Unnamed: 0  bicycle_id           start_time             end_time  \
# 0                0       86602  2015-01-01 00:04:00  2015-01-01 00:10:00
# 1                1       86157  2015-01-01 00:04:00  2015-01-01 00:16:00
# 2                2       86091  2015-01-01 00:08:00  2015-01-01 00:32:00
# 3                3       86908  2015-01-01 00:09:00  2015-01-01 00:29:00
# 4                4       86758  2015-01-01 00:10:00  2015-01-01 00:11:00
# ...            ...         ...                  ...                  ...
# 135479      135479       86568  2015-05-31 23:45:00  2015-06-01 00:00:00
# 135480      135480       86166  2015-05-31 23:46:00  2015-06-01 00:01:00
# 135481      135481       86201  2015-05-31 23:46:00  2015-06-01 00:01:00
# 135482      135482       86909  2015-05-31 23:52:00  2015-06-01 00:03:00
# 135483      135483       86544  2015-05-31 23:54:00  2015-06-01 00:04:00
#
#         start_location  end_location   rounded_start_time  \
# ...

# %%
# Assuming your DataFrames are named 'location' and 'weather'
merged_df = location.merge(weather, left_on='merge_id', right_on='merge_id_w', how='left')

# Display the merged DataFrame
print(merged_df.head())
# Out:
#    bicycle_id           start_time             end_time  start_location  \
# 0       86602  2015-01-01 00:04:00  2015-01-01 00:10:00             802
# 1       86157  2015-01-01 00:04:00  2015-01-01 00:16:00             802
# 2       86091  2015-01-01 00:08:00  2015-01-01 00:32:00             513
# 3       86908  2015-01-01 00:09:00  2015-01-01 00:29:00             513
# 4       86758  2015-01-01 00:10:00  2015-01-01 00:11:00             508
#
#    end_location rounded_start_time       year_month_day        merge_id  \
# 0           508           00:00:00  2015-01-01 00:00:00  20150101000000
# 1           508           00:00:00  2015-01-01 00:00:00  20150101000000
# 2          1106           00:00:00  2015-01-01 00:00:00  20150101000000
# 3           604           00:00:00  2015-01-01 00:00:00  20150101000000
# 4           508           00:00:00  2015-01-01 00:00:00  20150101000000
#
#                   time  tempm   hum  wspdm  pressurem  windchillm  fog  rain  \
# ...

# %%
merged_df.head()
# Out:
#    bicycle_id           start_time             end_time  start_location  \
# 0       86602  2015-01-01 00:04:00  2015-01-01 00:10:00             802
# 1       86157  2015-01-01 00:04:00  2015-01-01 00:16:00             802
# 2       86091  2015-01-01 00:08:00  2015-01-01 00:32:00             513
# 3       86908  2015-01-01 00:09:00  2015-01-01 00:29:00             513
# 4       86758  2015-01-01 00:10:00  2015-01-01 00:11:00             508
#
#    end_location rounded_start_time       year_month_day        merge_id  \
# 0           508           00:00:00  2015-01-01 00:00:00  20150101000000
# 1           508           00:00:00  2015-01-01 00:00:00  20150101000000
# 2          1106           00:00:00  2015-01-01 00:00:00  20150101000000
# 3           604           00:00:00  2015-01-01 00:00:00  20150101000000
# 4           508           00:00:00  2015-01-01 00:00:00  20150101000000
#
#                   time  tempm   hum  wspdm  pressurem  windchillm  fog  rain  \
# ...

# %%
merged_df.tail()
# Out:
#         bicycle_id           start_time             end_time  start_location  \
# 135479       86568  2015-05-31 23:45:00  2015-06-01 00:00:00             507
# 135480       86166  2015-05-31 23:46:00  2015-06-01 00:01:00             804
# 135481       86201  2015-05-31 23:46:00  2015-06-01 00:01:00             804
# 135482       86909  2015-05-31 23:52:00  2015-06-01 00:03:00             505
# 135483       86544  2015-05-31 23:54:00  2015-06-01 00:04:00            1302
#
#         end_location rounded_start_time       year_month_day        merge_id  \
# 135479           203           23:30:00  2015-05-31 23:30:00  20150531233000
# 135480           601           23:30:00  2015-05-31 23:30:00  20150531233000
# 135481           601           23:30:00  2015-05-31 23:30:00  20150531233000
# 135482           902           23:30:00  2015-05-31 23:30:00  20150531233000
# 135483           602           23:30:00  2015-05-31 23:30:00  20150531233000
#
# ...

# %%
merged_df.columns
# Out:
# Index(['bicycle_id', 'start_time', 'end_time', 'start_location',
#        'end_location', 'rounded_start_time', 'year_month_day', 'merge_id',
#        'time', 'tempm', 'hum', 'wspdm', 'pressurem', 'windchillm', 'fog',
#        'rain', 'snow', 'hail', 'thunder', 'merge_id_w'],
#       dtype='object')

# %%
merged_df[['bicycle_id', 'start_time', 'end_time', 'start_location',
       'end_location', 'rounded_start_time', 'year_month_day', 'merge_id',
       'time', 'tempm', 'hum', 'wspdm', 'pressurem', 'windchillm', 'fog',
       'rain', 'snow', 'hail', 'thunder', 'merge_id_w'
           #'start_day'
          ]]
# Out:
#         bicycle_id           start_time             end_time  start_location  \
# 0            86602  2015-01-01 00:04:00  2015-01-01 00:10:00             802
# 1            86157  2015-01-01 00:04:00  2015-01-01 00:16:00             802
# 2            86091  2015-01-01 00:08:00  2015-01-01 00:32:00             513
# 3            86908  2015-01-01 00:09:00  2015-01-01 00:29:00             513
# 4            86758  2015-01-01 00:10:00  2015-01-01 00:11:00             508
# ...            ...                  ...                  ...             ...
# 135479       86568  2015-05-31 23:45:00  2015-06-01 00:00:00             507
# 135480       86166  2015-05-31 23:46:00  2015-06-01 00:01:00             804
# 135481       86201  2015-05-31 23:46:00  2015-06-01 00:01:00             804
# 135482       86909  2015-05-31 23:52:00  2015-06-01 00:03:00             505
# 135483       86544  2015-05-31 23:54:00  2015-06-01 00:04:00            1302
#
# ...

# %%
merged_df['start_time'] = pd.to_datetime(merged_df['start_time'])
merged_df['end_time'] = pd.to_datetime(merged_df['end_time'])

# Calculate the duration
merged_df['duration'] = merged_df['end_time'] - merged_df['start_time']

# Display the DataFrame with the new 'duration' column
merged_df
# Out:
#         bicycle_id          start_time            end_time  start_location  \
# 0            86602 2015-01-01 00:04:00 2015-01-01 00:10:00             802
# 1            86157 2015-01-01 00:04:00 2015-01-01 00:16:00             802
# 2            86091 2015-01-01 00:08:00 2015-01-01 00:32:00             513
# 3            86908 2015-01-01 00:09:00 2015-01-01 00:29:00             513
# 4            86758 2015-01-01 00:10:00 2015-01-01 00:11:00             508
# ...            ...                 ...                 ...             ...
# 135479       86568 2015-05-31 23:45:00 2015-06-01 00:00:00             507
# 135480       86166 2015-05-31 23:46:00 2015-06-01 00:01:00             804
# 135481       86201 2015-05-31 23:46:00 2015-06-01 00:01:00             804
# 135482       86909 2015-05-31 23:52:00 2015-06-01 00:03:00             505
# 135483       86544 2015-05-31 23:54:00 2015-06-01 00:04:00            1302
#
# ...

# %%
merged_df.to_csv('merged_df2.csv', index=True)

# %%
merged_df['start_time'] = pd.to_datetime(merged_df['start_time'])
merged_df['end_time'] = pd.to_datetime(merged_df['end_time'])

# Calculate the duration in minutes
merged_df['duration_minutes'] = (merged_df['end_time'] - merged_df['start_time']).dt.total_seconds() / 60

# Display the DataFrame with the new 'duration_minutes' column
merged_df[['start_time', 'end_time', 'duration_minutes']]
# Out:
#                 start_time            end_time  duration_minutes
# 0      2015-01-01 00:04:00 2015-01-01 00:10:00               6.0
# 1      2015-01-01 00:04:00 2015-01-01 00:16:00              12.0
# 2      2015-01-01 00:08:00 2015-01-01 00:32:00              24.0
# 3      2015-01-01 00:09:00 2015-01-01 00:29:00              20.0
# 4      2015-01-01 00:10:00 2015-01-01 00:11:00               1.0
# ...                    ...                 ...               ...
# 135479 2015-05-31 23:45:00 2015-06-01 00:00:00              15.0
# 135480 2015-05-31 23:46:00 2015-06-01 00:01:00              15.0
# 135481 2015-05-31 23:46:00 2015-06-01 00:01:00              15.0
# 135482 2015-05-31 23:52:00 2015-06-01 00:03:00              11.0
# 135483 2015-05-31 23:54:00 2015-06-01 00:04:00              10.0
#
# [135484 rows x 3 columns]

# %%
merged_df
# Out:
#         bicycle_id          start_time            end_time  start_location  \
# 0            86602 2015-01-01 00:04:00 2015-01-01 00:10:00             802
# 1            86157 2015-01-01 00:04:00 2015-01-01 00:16:00             802
# 2            86091 2015-01-01 00:08:00 2015-01-01 00:32:00             513
# 3            86908 2015-01-01 00:09:00 2015-01-01 00:29:00             513
# 4            86758 2015-01-01 00:10:00 2015-01-01 00:11:00             508
# ...            ...                 ...                 ...             ...
# 135479       86568 2015-05-31 23:45:00 2015-06-01 00:00:00             507
# 135480       86166 2015-05-31 23:46:00 2015-06-01 00:01:00             804
# 135481       86201 2015-05-31 23:46:00 2015-06-01 00:01:00             804
# 135482       86909 2015-05-31 23:52:00 2015-06-01 00:03:00             505
# 135483       86544 2015-05-31 23:54:00 2015-06-01 00:04:00            1302
#
# ...

# %%
merged_df.to_csv('merged_df2.csv', index=True)

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 135484 entries, 0 to 135483
# Data columns (total 22 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   bicycle_id          135484 non-null  int64
#  1   start_time          135484 non-null  datetime64[ns]
#  2   end_time            135484 non-null  datetime64[ns]
#  3   start_location      135484 non-null  int64
#  4   end_location        135484 non-null  int64
#  5   rounded_start_time  135484 non-null  object
#  6   year_month_day      135484 non-null  object
#  7   merge_id            135484 non-null  int64
#  8   time                135294 non-null  object
#  9   tempm               135294 non-null  float64
#  10  hum                 135294 non-null  float64
#  11  wspdm               135294 non-null  float64
#  12  pressurem           135294 non-null  float64
#  13  windchillm          135294 non-null  float64
#  14  fog                 135294 non-null  float64
# ...

# %%
merged_df_corrM = merged_df[[
    #'bicycle_id', 'start_time', 'end_time', 'start_location',
       #'end_location', 'rounded_start_time', 'year_month_day', 'merge_id',
       #'time', 
    'tempm', 'hum', 'wspdm', 'pressurem', 'windchillm', 'fog',
       'rain', 'snow', 'hail', 'thunder', 
    #'merge_id_w'
           #'start_day','duration', 
    'duration_minutes'
          ]]

# %%
corrM= merged_df.corr()
corrM
# Out:
# C:\Users\nagyn\AppData\Local\Temp\ipykernel_25568\1536604234.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corrM= merged_df.corr()
#                   bicycle_id  start_location  end_location  merge_id  \
# bicycle_id          1.000000        0.003823      0.004461  0.016855
# start_location      0.003823        1.000000      0.224757  0.026354
# end_location        0.004461        0.224757      1.000000  0.028083
# merge_id            0.016855        0.026354      0.028083  1.000000
# tempm               0.013709        0.030241      0.025929  0.769661
# hum                -0.004845       -0.025299     -0.018633 -0.387614
# wspdm              -0.001060       -0.001109      0.002427  0.088546
# pressurem           0.000093        0.006469      0.003564 -0.139375
# ...

# %%
merged_df_corrM.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 135484 entries, 0 to 135483
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   tempm             135294 non-null  float64
#  1   hum               135294 non-null  float64
#  2   wspdm             135294 non-null  float64
#  3   pressurem         135294 non-null  float64
#  4   windchillm        135294 non-null  float64
#  5   fog               135294 non-null  float64
#  6   rain              135294 non-null  float64
#  7   snow              135294 non-null  float64
#  8   hail              135294 non-null  float64
#  9   thunder           135294 non-null  float64
#  10  duration_minutes  135484 non-null  float64
# dtypes: float64(11)
# memory usage: 12.4 MB

# %%
corrM = merged_df_corrM.corr()
corrM
# Out:
#                      tempm       hum     wspdm  pressurem  windchillm  \
# tempm             1.000000 -0.572040  0.234091  -0.281848    0.995654
# hum              -0.572040  1.000000 -0.313157  -0.213550   -0.558202
# wspdm             0.234091 -0.313157  1.000000  -0.183720    0.187631
# pressurem        -0.281848 -0.213550 -0.183720   1.000000   -0.273809
# windchillm        0.995654 -0.558202  0.187631  -0.273809    1.000000
# fog              -0.102462  0.129926 -0.073679  -0.001248   -0.095956
# rain             -0.055621  0.227418  0.038191  -0.156506   -0.057450
# snow             -0.117308  0.116750 -0.014588  -0.079424   -0.125353
# hail                   NaN       NaN       NaN        NaN         NaN
# thunder           0.064287  0.032368 -0.028028  -0.024062    0.063597
# duration_minutes  0.064272 -0.048421  0.014585  -0.011998    0.064579
#
#                        fog      rain      snow  hail   thunder  \
# ...
